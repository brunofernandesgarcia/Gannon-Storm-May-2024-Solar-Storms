# %% [markdown]
# # Gráficos: Flare Recurrence e Quantidades AR13663

# %% [markdown]
# ### Fase de testes... As primeiras linhas estão confusas, mas estava treinando e encontrando as melhores ferramentas para o código. Decidi não apagar, para servir de aprendizagem :)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carregando a planilha

# %%
df = pd.read_excel('C:/Users/bruno/OneDrive/Área de Trabalho/SOLAR_AI_GROUP/paper_solar_physics+ai/dados_analises_may_2024_flares.xlsx')

# Visualizar os primeiros dados
df.head()
# Out:
#             Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                  NaN         NaN         NaN         NaN         NaN
# 1                  NaN         NaN         NaN         NaN         NaN
# 2                   AR     13663.0         NaN         NaN         NaN
# 3  2024-05-01 00:00:00         4.0         NaN         NaN         NaN
# 4  2024-05-02 00:00:00         5.0         NaN         NaN         NaN
#
#             Unnamed: 5  Unnamed: 6
# 0                  NaN         NaN
# 1                  NaN         NaN
# 2                   AR     13664.0
# 3  2024-05-01 00:00:00         0.0
# 4  2024-05-02 00:00:00         6.0

# %%
xls = pd.ExcelFile('C:/Users/bruno/OneDrive/Área de Trabalho/SOLAR_AI_GROUP/paper_solar_physics+ai/dados_analises_may_2024_flares.xlsx')
print(xls.sheet_names)  # Isso mostrará os nomes de todas as abas
# Out:
# ['qtd_flare_per_day', 'Class_flare_per_day', 'time_flare_interval_AR13663', 'time_flare_interval_AR13664']

# %%
df = pd.read_excel('C:/Users/bruno/OneDrive/Área de Trabalho/SOLAR_AI_GROUP/paper_solar_physics+ai/dados_analises_may_2024_flares.xlsx', sheet_name='time_flare_interval_AR13663')
# Exibir todas as 40 linhas
pd.set_option('display.max_rows', 40)

# Exibir o DataFrame completo
print(df)
# Out:
#     Recurrence Time  Quantities
# 0                 1          37
# 1                 2          14
# 2                 3           9
# 3                 4           5
# 4                 5           3
# 5                 6           4
# 6                 7           2
# 7                 8           0
# 8                 9           1
# 9                10           0
# 10               11           1
# 11               12           0
# 12               13           0
# 13               14           0
# 14               15           0
# 15               16           0
# 16               17           0
# 17               18           0
# 18               19           0
# 19               20           0
# 20               21           0
# 21               22           0
# 22               23           0
# 23               24           0
# 24               25           0
# 25               26           0
# 26               27           0
# 27               28           0
# ...

# %% [markdown]
# ## Gerando o gráfico...

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(recurrence_time, quantities, color='orange')

# Adicionar título e rótulos
plt.title('AR 13663\n80 flares', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=12)
plt.ylabel('# of events', fontsize=12)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir o gráfico
plt.show()

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Definir a largura da barra como o intervalo de 1 unidade (intervalo de tempo)
bar_width = 1.0

# Criar o gráfico de barras ajustado
plt.figure(figsize=(10, 6))
plt.bar(recurrence_time, quantities, width=bar_width, color='orange', align='edge')

# Ajustar o alinhamento do eixo X para começar em 0
plt.xlim(left=0)

# Adicionar título e rótulos
plt.title('AR 13663\n80 flares', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=12)
plt.ylabel('# of events', fontsize=12)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir o gráfico
plt.show()

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Definir a largura da barra como o intervalo de 1 unidade (intervalo de tempo)
bar_width = 1.0

# Criar o gráfico de barras ajustado com bordas pretas
plt.figure(figsize=(10, 6))
plt.bar(recurrence_time, quantities, width=bar_width, color='orange', edgecolor='black', align='edge')

# Ajustar o alinhamento do eixo X para começar em 0
plt.xlim(left=0)

# Definir intervalos no eixo X de 2 em 2
plt.xticks(range(0, int(max(recurrence_time)) + 2, 2))

# Adicionar título e rótulos
plt.title('AR 13663\n80 flares', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=12)
plt.ylabel('# of events', fontsize=12)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir o gráfico
plt.show()

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Definir a largura da barra como o intervalo de 1 unidade (intervalo de tempo)
bar_width = 1.0

# Corrigir o deslocamento das barras para que representem o início do intervalo
adjusted_recurrence_time = recurrence_time - 1  # Desloca o Recurrence Time em 1 unidade para a esquerda

# Criar o gráfico de barras ajustado com bordas pretas e deslocamento correto
plt.figure(figsize=(10, 6))
plt.bar(adjusted_recurrence_time, quantities, width=bar_width, color='orange', edgecolor='black', align='edge')

# Ajustar o alinhamento do eixo X para começar em 0
plt.xlim(left=0)

# Definir intervalos no eixo X de 2 em 2
plt.xticks(range(0, int(max(recurrence_time)) + 2, 2))

# Adicionar título e rótulos
plt.title('AR 13663\n80 flares', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=12)
plt.ylabel('# of events', fontsize=12)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir o gráfico
plt.show()

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Definir os valores da média e mediana (substitua pelos seus valores)
media = 2.361  # Valor da média
mediana = 1.2  # Valor da mediana

# Definir a largura da barra como o intervalo de 1 unidade (intervalo de tempo)
bar_width = 1.0

# Corrigir o deslocamento das barras para que representem o início do intervalo
adjusted_recurrence_time = recurrence_time - 1  # Desloca o Recurrence Time em 1 unidade para a esquerda

# Criar o gráfico de barras ajustado com bordas pretas e deslocamento correto
plt.figure(figsize=(10, 6))
plt.bar(adjusted_recurrence_time, quantities, width=bar_width, color='orange', edgecolor='black', align='edge')

# Adicionar linha pontilhada para a média
plt.axvline(x=media, color='red', linestyle='--', linewidth=2, label=f'Ave {media} hrs')

# Adicionar linha pontilhada para a mediana
plt.axvline(x=mediana, color='green', linestyle='--', linewidth=2, label=f'Med {mediana} hrs')

# Adicionar rótulos para as linhas
plt.text(media + 0.5, max(quantities) - 5, f'Ave {media} hrs', color='red', fontsize=12, va='center')
plt.text(mediana + 0.5, max(quantities) - 10, f'Med {mediana} hrs', color='green', fontsize=12, va='center')

# Ajustar o alinhamento do eixo X para começar em 0
plt.xlim(left=0)

# Definir intervalos no eixo X de 2 em 2
plt.xticks(range(0, int(max(recurrence_time)) + 2, 2))

# Adicionar título e rótulos
plt.title('AR 13663\nTotal Flares: 80', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=12)
plt.ylabel('Number of Flares', fontsize=12)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir a legenda
plt.legend()

plt.savefig('grafico_recurrence_time_AR13663.png', dpi=300, bbox_inches='tight')  # Salva em PNG 

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Finalmente, o correto! Começando pela AR13663

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Definir os valores da média e mediana em horas decimais
media = 2 + 21/60 + 42/3600  # Média 2 horas, 21 minutos, 42 segundos (2.3617 horas)
mediana = 1 + 12/60 + 0/3600  # Mediana 1 hora, 12 minutos, 0 segundos (1.2 horas)

# Definir a largura da barra como o intervalo de 1 unidade (intervalo de tempo)
bar_width = 1.0

# Corrigir o deslocamento das barras para que representem o início do intervalo
adjusted_recurrence_time = recurrence_time - 1  # Desloca o Recurrence Time em 1 unidade para a esquerda

# Criar o gráfico de barras ajustado com bordas pretas e deslocamento correto
plt.figure(figsize=(10, 6))
plt.bar(adjusted_recurrence_time, quantities, width=bar_width, color='orange', edgecolor='black', align='edge')

# Adicionar linha pontilhada para a média
plt.axvline(x=media, color='red', linestyle='--', linewidth=2, label=f'Ave {media:.3f} hrs')

# Adicionar linha pontilhada para a mediana
plt.axvline(x=mediana, color='green', linestyle='--', linewidth=2, label=f'Med {mediana:.1f} hrs')

# Adicionar setas e rótulos mais distantes das linhas
plt.annotate(f'Ave {media:.3f} hrs', xy=(media, max(quantities) - 5), xytext=(media + 5, max(quantities) - 5),
             arrowprops=dict(facecolor='red', shrink=0.05, width=2), color='red', fontsize=16)

plt.annotate(f'Med {mediana:.1f} hrs', xy=(mediana, max(quantities) - 10), xytext=(mediana + 5, max(quantities) - 10),
             arrowprops=dict(facecolor='green', shrink=0.05, width=2), color='green', fontsize=16)

# Ajustar o alinhamento do eixo X para começar em 0
plt.xlim(left=0)

# Definir intervalos no eixo X de 2 em 2
plt.xticks(range(0, int(max(recurrence_time)) + 2, 2))

# Adicionar título e rótulos
plt.title('AR 13663\nTotal Flares: 80', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=16)
plt.ylabel('Number of Flares', fontsize=16)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir a legenda
plt.legend()

# Salvar o gráfico como PNG ou JPG
plt.savefig('grafico_recurrence_time_AR13663.png', dpi=300, bbox_inches='tight')  # Salva em PNG 
# plt.savefig('grafico_recurrence_time.jpg', dpi=300, bbox_inches='tight')  # Salva em JPG (opcional)

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Agora, a AR13664

# %%
# Supondo que você já tenha lido os dados em um DataFrame chamado 'df'
# df = pd.read_excel('caminho_para_o_seu_arquivo/dados.xlsx')

# Extraindo as colunas relevantes: Recurrence Time e Quantities
recurrence_time = df['Recurrence Time']
quantities = df['Quantities']

# Definir os valores da média e mediana em horas decimais
media = 3 + 35/60 + 28/3600  # Média 3 horas, 35 minutos, 28 segundos (3.591 horas)
mediana = 1 + 37/60 + 0/3600  # Mediana 1 hora, 37 minutos, 0 segundos (1.6 horas)

# Definir a largura da barra como o intervalo de 1 unidade (intervalo de tempo)
bar_width = 1.0

# Corrigir o deslocamento das barras para que representem o início do intervalo
adjusted_recurrence_time = recurrence_time - 1  # Desloca o Recurrence Time em 1 unidade para a esquerda

# Criar o gráfico de barras ajustado com bordas pretas e deslocamento correto
plt.figure(figsize=(10, 6))
plt.bar(adjusted_recurrence_time, quantities, width=bar_width, color='orange', edgecolor='black', align='edge')

# Adicionar linha pontilhada para a média
plt.axvline(x=media, color='red', linestyle='--', linewidth=2, label=f'Ave {media:.3f} hrs')

# Adicionar linha pontilhada para a mediana
plt.axvline(x=mediana, color='green', linestyle='--', linewidth=2, label=f'Med {mediana:.1f} hrs')

# Adicionar setas e rótulos mais distantes das linhas
plt.annotate(f'Ave {media:.3f} hrs', xy=(media, max(quantities) - 5), xytext=(media + 5, max(quantities) - 5),
             arrowprops=dict(facecolor='red', shrink=0.05, width=2), color='red', fontsize=16)

plt.annotate(f'Med {mediana:.1f} hrs', xy=(mediana, max(quantities) - 10), xytext=(mediana + 5, max(quantities) - 10),
             arrowprops=dict(facecolor='green', shrink=0.05, width=2), color='green', fontsize=16)

# Ajustar o alinhamento do eixo X para começar em 0
plt.xlim(left=0)

# Definir intervalos no eixo X de 2 em 2
plt.xticks(range(0, int(max(recurrence_time)) + 2, 2))

# Adicionar título e rótulos
plt.title('AR 13664\nTotal Flares: 83', fontsize=16)
plt.xlabel('Flare Recurrence Time [hrs]', fontsize=16)
plt.ylabel('Number of Flares', fontsize=16)

# Ajustar os limites do eixo y para garantir que a contagem de eventos comece em 0
plt.ylim(0, max(quantities) + 5)

# Exibir a legenda
plt.legend()

# Salvar o gráfico como PNG ou JPG
plt.savefig('grafico_recurrence_time_AR13664.png', dpi=300, bbox_inches='tight')  # Salva em PNG 
# plt.savefig('grafico_recurrence_time.jpg', dpi=300, bbox_inches='tight')  # Salva em JPG (opcional)

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Quantidade Flare por dia!

# %%
xls = pd.ExcelFile('C:/Users/bruno/OneDrive/Área de Trabalho/SOLAR_AI_GROUP/paper_solar_physics+ai/dados_analises_may_2024_flares.xlsx')
print(xls.sheet_names)  # Isso mostrará os nomes de todas as abas
# Out:
# ['qtd_flare_per_day', 'Class_flare_per_day', 'time_flare_interval_AR13663', 'time_flare_interval_AR13664']

# %%
df = pd.read_excel('C:/Users/bruno/OneDrive/Área de Trabalho/SOLAR_AI_GROUP/paper_solar_physics+ai/dados_analises_may_2024_flares.xlsx', sheet_name='qtd_flare_per_day')
# Exibir todas as 40 linhas
#pd.set_option('display.max_rows', 40)

# Exibir o DataFrame completo
print(df)
# Out:
#              Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                   NaN         NaN         NaN         NaN         NaN
# 1                   NaN         NaN         NaN         NaN         NaN
# 2                    AR     13663.0         NaN         NaN         NaN
# 3   2024-05-01 00:00:00         4.0         NaN         NaN         NaN
# 4   2024-05-02 00:00:00         5.0         NaN         NaN         NaN
# 5   2024-05-03 00:00:00         8.0         NaN         NaN         NaN
# 6   2024-05-04 00:00:00        18.0         NaN         NaN         NaN
# 7   2024-05-05 00:00:00        15.0         NaN         NaN         NaN
# 8   2024-05-06 00:00:00        16.0         NaN         NaN         NaN
# 9   2024-05-07 00:00:00         7.0         NaN         NaN         NaN
# 10  2024-05-08 00:00:00         6.0         NaN         NaN         NaN
# 11  2024-05-09 00:00:00         0.0         NaN         NaN         NaN
# ...

# %% [markdown]
# ## Gerando o gráfico...

# %% [markdown]
# AR13663

# %%
dados_ar13663 = {
    'Date': ['2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04', '2024-05-05',
             '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10',
             '2024-05-11', '2024-05-12', '2024-05-13', '2024-05-14', '2024-05-15'],
    'qtd_flares_ar13663': [4, 5, 8, 18, 15, 16, 7, 6, 0, 1, 0, 0, 0, 0, 0]
}

df_ar13663 = pd.DataFrame(dados_ar13663)

df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(10, 6))

plt.plot(df['Date'], df['qtd_flares_ar13663'], label='AR13663', color='yellow')

plt.title('Quantities of flare per day', fontsize=16)

plt.ylabel('Quantities', fontsize=12)
plt.ylim(0, 20)
plt.yticks(range(0, 20, 2))
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

plt.savefig('flare_per_day_ar13663.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 10
#       1 dados_ar13663 = {
# ...

# %% [markdown]
# AR13664

# %%
dados_ar13664 = {
    'Date': ['2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04', '2024-05-05',
             '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10',
             '2024-05-11', '2024-05-12', '2024-05-13', '2024-05-14', '2024-05-15'],
    'qtd_flares_ar13664': [0, 6, 4, 1, 5, 0, 2, 9, 9, 13, 8, 7, 13, 4, 1]
}

df_ar13664 = pd.DataFrame(dados_ar13664)

df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(10, 6))

plt.plot(df['Date'], df['qtd_flares_ar13664'], label='AR13664', color='purple')

plt.title('Amount of Flares over the days', fontsize=16)

plt.ylabel('Quantities', fontsize=12)
plt.ylim(0, 20)
plt.yticks(range(0, 20, 2))
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

plt.savefig('flare_per_day_ar13664', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# As duas regiões ativas juntas agora...

# %%
dados_ar13663 = {
    'Date': ['2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04', '2024-05-05',
             '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10',
             '2024-05-11', '2024-05-12', '2024-05-13', '2024-05-14', '2024-05-15'],
    'qtd_flares_ar13663': [4, 5, 8, 18, 15, 16, 7, 6, 0, 1, 0, 0, 0, 0, 0]
}

dados_ar13664 = {
    'Date': ['2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04', '2024-05-05',
             '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10',
             '2024-05-11', '2024-05-12', '2024-05-13', '2024-05-14', '2024-05-15'],
    'qtd_flares_ar13664': [0, 6, 4, 1, 5, 0, 2, 9, 9, 13, 8, 7, 13, 4, 1]
}

df_ar13663 = pd.DataFrame(dados_ar13663)
df_ar13664 = pd.DataFrame(dados_ar13664)

df = pd.merge(df_ar13663, df_ar13664, on='Date')

df['Total_Flares'] = df['qtd_flares_ar13663'] + df['qtd_flares_ar13664']

df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12, 7))

plt.plot(df['Date'], df['qtd_flares_ar13663'], label='AR13663', color='orange')

plt.plot(df['Date'], df['qtd_flares_ar13664'], label='AR13664', color='purple')

#plt.title('Amount of Flares over the days', fontsize=16)
#plt.ylabel('Quantities', fontsize=14)

plt.title('Amount of Flares Over the Days', fontsize=20, fontweight='bold')

plt.ylim(0, 20)
plt.yticks(range(0, 20, 2), fontsize=16)
plt.xticks(rotation=45, fontsize=16)
plt.legend(fontsize=14, loc='upper right')

plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()

plt.savefig('amount_flare_over_days.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Classes Flare ao longo dos dias

# %%
# Caminho do arquivo Excel (ajuste conforme necessário)
file_path = 'C:/Users/bruno/OneDrive/Área de Trabalho/SOLAR_AI_GROUP/paper_solar_physics+ai/dados_analises_may_2024_flares.xlsx'

# Ler os dados da aba correta
data = pd.read_excel(file_path, sheet_name='Class_flare_per_day')

# %% [markdown]
# AR13663

# %%
# Filtrar os dados relevantes para AR13663
flare_ar13663 = data[['AR13663', 'C-Class', 'M-Class', 'X-Class']].copy()
flare_ar13663.rename(columns={'AR13663': 'Date'}, inplace=True)
flare_ar13663['Date'] = pd.to_datetime(flare_ar13663['Date'])

# Filtrar até o dia 10/05/2024
flare_ar13663_filtered = flare_ar13663[flare_ar13663['Date'] <= '2024-05-10']

# Definir posições no eixo X
x_positions_filtered = np.arange(len(flare_ar13663_filtered['Date']))
bar_width = 0.25
x_c_filtered = x_positions_filtered - bar_width
x_m_filtered = x_positions_filtered
x_x_filtered = x_positions_filtered + bar_width

# Gerar o gráfico
plt.figure(figsize=(12, 6))
plt.bar(x_c_filtered, flare_ar13663_filtered['C-Class'], bar_width, label='C', color='blue', edgecolor='black')
plt.bar(x_m_filtered, flare_ar13663_filtered['M-Class'], bar_width, label='M', color='green', edgecolor='black')
plt.bar(x_x_filtered, flare_ar13663_filtered['X-Class'], bar_width, label='X', color='red', edgecolor='black')

# Configurações do gráfico
plt.ylabel("Number of Flares", fontsize=16)
plt.title("Number of Flares per Day by Class (AR13663)", fontsize=16)
plt.legend(title="Flare Class", fontsize=20)
plt.xticks(x_positions_filtered, flare_ar13663_filtered['Date'].dt.strftime('%Y-%m-%d'), rotation=45, fontsize=16)
plt.tight_layout()

plt.savefig('number_flares_class_AR13663.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico
plt.show()

# %% [markdown]
# AR13664

# %%
# Filtrar os dados relevantes para AR13664
flare_ar13664 = data[['AR13664', 'C-Class.1', 'M-Class.1', 'X-Class.1']].copy()
flare_ar13664.rename(columns={
    'AR13664': 'Date',
    'C-Class.1': 'C-Class',
    'M-Class.1': 'M-Class',
    'X-Class.1': 'X-Class'
}, inplace=True)
flare_ar13664['Date'] = pd.to_datetime(flare_ar13664['Date'])

# Filtrar até o dia 10/05/2024
flare_ar13664_filtered = flare_ar13664[flare_ar13664['Date'] <= '2024-05-15']

# Definir posições no eixo X
x_positions_filtered = np.arange(len(flare_ar13664_filtered['Date']))
bar_width = 0.25
x_c_filtered = x_positions_filtered - bar_width
x_m_filtered = x_positions_filtered
x_x_filtered = x_positions_filtered + bar_width

# Gerar o gráfico
plt.figure(figsize=(12, 6))
plt.bar(x_c_filtered, flare_ar13664_filtered['C-Class'], bar_width, label='C', color='blue', edgecolor='black')
plt.bar(x_m_filtered, flare_ar13664_filtered['M-Class'], bar_width, label='M', color='green', edgecolor='black')
plt.bar(x_x_filtered, flare_ar13664_filtered['X-Class'], bar_width, label='X', color='red', edgecolor='black')

# Configurações do gráfico
plt.ylabel("Number of Flares", fontsize=16)
plt.title("Number of Flares per Day by Class (AR13664)", fontsize=20)
plt.legend(title="Flare Class", fontsize=16)
plt.xticks(x_positions_filtered, flare_ar13664_filtered['Date'].dt.strftime('%Y-%m-%d'), rotation=45, fontsize=16)
plt.tight_layout()

plt.savefig('number_flares_class_AR13664.png', dpi=300, bbox_inches='tight')

# Exibir o gráfico
plt.show()
